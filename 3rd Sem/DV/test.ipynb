# %%
import numpy as np

arr1 = np.array([
    [0,1,0], 
    [2/3,0,1/3],
    [0,1,0]
])

arr2 = np.array([[0,0,1]])

result =  arr1 @ arr1

# %%
result = result@result
result
# Out:
# array([[0.66666667, 0.        , 0.33333333],
#        [0.        , 1.        , 0.        ],
#        [0.66666667, 0.        , 0.33333333]])
